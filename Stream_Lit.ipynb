# %%
import pandas as pd

# %%
df = pd.read_csv("/content/agriculture-and-rural-development_lka.csv")
df
# Out:
#        Country Name   Country ISO3        Year  \
# 0     #country+name  #country+code  #date+year
# 1         Sri Lanka            LKA        2022
# 2         Sri Lanka            LKA        2021
# 3         Sri Lanka            LKA        2020
# 4         Sri Lanka            LKA        2019
# ...             ...            ...         ...
# 1687      Sri Lanka            LKA        1966
# 1688      Sri Lanka            LKA        1965
# 1689      Sri Lanka            LKA        1964
# 1690      Sri Lanka            LKA        1963
# 1691      Sri Lanka            LKA        1962
#
#                                          Indicator Name     Indicator Code  \
# 0                                       #indicator+name    #indicator+code
# 1     Fertilizer consumption (% of fertilizer produc...  AG.CON.FERT.PT.ZS
# 2     Fertilizer consumption (% of fertilizer produc...  AG.CON.FERT.PT.ZS
# 3     Fertilizer consumption (% of fertilizer produc...  AG.CON.FERT.PT.ZS
# ...

# %%
df.columns
# Out:
# Index(['Country Name', 'Country ISO3', 'Year', 'Indicator Name',
#        'Indicator Code', 'Value'],
#       dtype='object')

# %%
df.shape
# Out:
# (1692, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    1692 non-null   object
#  1   Country ISO3    1692 non-null   object
#  2   Year            1692 non-null   object
#  3   Indicator Name  1692 non-null   object
#  4   Indicator Code  1692 non-null   object
#  5   Value           1692 non-null   object
# dtypes: object(6)
# memory usage: 79.4+ KB

# %%
df.describe()
# Out:
#        Country Name Country ISO3  Year  \
# count          1692         1692  1692
# unique            2            2    65
# top       Sri Lanka          LKA  2015
# freq           1691         1691    35
#
#                                            Indicator Name  Indicator Code  \
# count                                                1692            1692
# unique                                                 36              36
# top     Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.CD
# freq                                                   64              64
#
#         Value
# count    1692
# unique   1389
# top     65610
# freq       62

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# Country Name      0
# Country ISO3      0
# Year              0
# Indicator Name    0
# Indicator Code    0
# Value             0
# dtype: int64

# %%
duplicated_values = df.duplicated().sum()
duplicated_values
# Out:
# np.int64(0)

# %%
print(f"Number of unique values:{df['Country Name'].nunique()}")
print(f"Unique values:{df['Country Name'].unique()}")
# Out:
# Number of unique values:2
# Unique values:['#country+name' 'Sri Lanka']

# %%
print(f"Number of unique values:{df['Country ISO3'].nunique()}")
print(f"Unique values:{df['Country ISO3'].unique()}")
# Out:
# Number of unique values:2
# Unique values:['#country+code' 'LKA']

# %%
print(f"Number of unique values:{df['Year'].nunique()}")
print(f"Unique values:{df['Year'].unique()}")
# Out:
# Number of unique values:65
# Unique values:['#date+year' '2022' '2021' '2020' '2019' '2018' '2017' '2016' '2015'
#  '2014' '2013' '2012' '2011' '2010' '2009' '2008' '2007' '2006' '2005'
#  '2004' '2003' '2002' '2001' '2000' '1999' '1998' '1997' '1996' '1995'
#  '1994' '1993' '1992' '1991' '1990' '1989' '1988' '1987' '1986' '1985'
#  '1984' '1983' '1982' '1981' '1980' '1979' '1978' '1977' '1976' '1975'
#  '1974' '1973' '1972' '1971' '1970' '1969' '1968' '1967' '1966' '1965'
#  '1964' '1963' '1962' '1961' '2023' '1960']

# %%
print(f"Number of unique values:{df['Indicator Name'].nunique()}")
print(f"Unique values:{df['Indicator Name'].unique()}")
# Out:
# Number of unique values:36
# Unique values:['#indicator+name' 'Fertilizer consumption (% of fertilizer production)'
#  'Fertilizer consumption (kilograms per hectare of arable land)'
#  'Agricultural land (sq. km)' 'Agricultural land (% of land area)'
#  'Arable land (hectares)' 'Arable land (hectares per person)'
#  'Arable land (% of land area)' 'Land under cereal production (hectares)'
#  'Permanent cropland (% of land area)'
#  'Rural land area where elevation is below 5 meters (sq. km)'
#  'Rural land area where elevation is below 5 meters (% of total land area)'
#  'Forest area (sq. km)' 'Forest area (% of land area)'
#  'Average precipitation in depth (mm per year)' 'Land area (sq. km)'
#  'Rural land area (sq. km)' 'Cereal production (metric tons)'
#  'Crop production index (2014-2016 = 100)'
#  'Food production index (2014-2016 = 100)'
#  'Livestock production index (2014-2016 = 100)' 'Surface area (sq. km)'
#  'Cereal yield (kg per hectare)'
# ...

# %%
print(f"Number of unique values:{df['Indicator Code'].nunique()}")
print(f"Unique values:{df['Indicator Code'].unique()}")
# Out:
# Number of unique values:36
# Unique values:['#indicator+code' 'AG.CON.FERT.PT.ZS' 'AG.CON.FERT.ZS' 'AG.LND.AGRI.K2'
#  'AG.LND.AGRI.ZS' 'AG.LND.ARBL.HA' 'AG.LND.ARBL.HA.PC' 'AG.LND.ARBL.ZS'
#  'AG.LND.CREL.HA' 'AG.LND.CROP.ZS' 'AG.LND.EL5M.RU.K2' 'AG.LND.EL5M.RU.ZS'
#  'AG.LND.FRST.K2' 'AG.LND.FRST.ZS' 'AG.LND.PRCP.MM' 'AG.LND.TOTL.K2'
#  'AG.LND.TOTL.RU.K2' 'AG.PRD.CREL.MT' 'AG.PRD.CROP.XD' 'AG.PRD.FOOD.XD'
#  'AG.PRD.LVSK.XD' 'AG.SRF.TOTL.K2' 'AG.YLD.CREL.KG' 'EG.ELC.ACCS.RU.ZS'
#  'EN.POP.EL5M.RU.ZS' 'ER.H2O.FWAG.ZS' 'NV.AGR.TOTL.CD' 'NV.AGR.TOTL.ZS'
#  'SL.AGR.EMPL.FE.ZS' 'SL.AGR.EMPL.MA.ZS' 'SL.AGR.EMPL.ZS' 'SP.RUR.TOTL'
#  'SP.RUR.TOTL.ZG' 'SP.RUR.TOTL.ZS' 'TM.VAL.AGRI.ZS.UN' 'TX.VAL.AGRI.ZS.UN']

# %%
print(f"Number of unique values:{df['Value'].nunique()}")
print(f"Unique values:{df['Value'].unique()}")
# Out:
# Number of unique values:1389
# Unique values:['#indicator+value+num' '1461.39775839426' '2838.09421995635' ...
#  '19.1296091397388' '17.8033266019983' '18.8879692586191']

# %%
df = df.drop(["Country Name","Country ISO3",], axis = 1)
df = df.iloc[1:]
df
# Out:
#       Year                                     Indicator Name  \
# 1     2022  Fertilizer consumption (% of fertilizer produc...
# 2     2021  Fertilizer consumption (% of fertilizer produc...
# 3     2020  Fertilizer consumption (% of fertilizer produc...
# 4     2019  Fertilizer consumption (% of fertilizer produc...
# 5     2018  Fertilizer consumption (% of fertilizer produc...
# ...    ...                                                ...
# 1687  1966  Agricultural raw materials exports (% of merch...
# 1688  1965  Agricultural raw materials exports (% of merch...
# 1689  1964  Agricultural raw materials exports (% of merch...
# 1690  1963  Agricultural raw materials exports (% of merch...
# 1691  1962  Agricultural raw materials exports (% of merch...
#
#          Indicator Code             Value
# 1     AG.CON.FERT.PT.ZS  1461.39775839426
# 2     AG.CON.FERT.PT.ZS  1461.39775839426
# 3     AG.CON.FERT.PT.ZS  2838.09421995635
# 4     AG.CON.FERT.PT.ZS  1803.55490605544
# ...

# %%
df["Value"] = df["Value"].astype(float).round(2)
df.dtypes
# Out:
# Year               object
# Indicator Name     object
# Indicator Code     object
# Value             float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1691 entries, 1 to 1691
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            1691 non-null   object
#  1   Indicator Name  1691 non-null   object
#  2   Indicator Code  1691 non-null   object
#  3   Value           1691 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 53.0+ KB

# %%
df.describe()
# Out:
#               Value
# count  1.691000e+03
# mean   1.101640e+08
# std    7.058795e+08
# min   -2.800000e+00
# 25%    2.652500e+01
# 50%    8.520000e+01
# 75%    6.271000e+04
# max    7.788707e+09

# %%
df.to_csv("agriculture_and_rural.csv", index = False)
